# %%
pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\jo ron\anaconda3\lib\site-packages (1.3.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<2.0,>=1.17.3 in c:\users\jo ron\anaconda3\lib\site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\jo ron\anaconda3\lib\site-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\jo ron\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\jo ron\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("water_potability.csv")
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
df['ph'] = df['ph'].fillna(df['ph'].mean())
df['Sulfate'] = df['Sulfate'].fillna(df['Sulfate'].mean())
df['Trihalomethanes'] = df['Trihalomethanes'].fillna(df['Trihalomethanes'].mean())

# %%
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225        66.396293   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
X = df.drop('Potability', axis=1)
y = df['Potability']
X.shape, y.shape
scaler = StandardScaler()
X = scaler.fit_transform(X)
X
# Out:
# array([[-6.04313345e-16,  2.59194711e-01, -1.39470871e-01, ...,
#         -1.18065057e+00,  1.30614943e+00, -1.28629758e+00],
#        [-2.28933938e+00, -2.03641367e+00, -3.85986650e-01, ...,
#          2.70597240e-01, -6.38479983e-01,  6.84217891e-01],
#        [ 6.92867789e-01,  8.47664833e-01, -2.40047337e-01, ...,
#          7.81116857e-01,  1.50940884e-03, -1.16736546e+00],
#        ...,
#        [ 1.59125368e+00, -6.26829230e-01,  1.27080989e+00, ...,
#         -9.81329234e-01,  2.18748247e-01, -8.56006782e-01],
#        [-1.32951593e+00,  1.04135450e+00, -1.14405809e+00, ...,
#         -9.42063817e-01,  7.03468419e-01,  9.50797383e-01],
#        [ 5.40150905e-01, -3.85462310e-02, -5.25811937e-01, ...,
#          5.60940070e-01,  7.80223466e-01, -2.12445866e+00]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
# Initialize the Random Forest Regressor
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
rf_regressor.fit(X_train, y_train)

# Make predictions on the test set
predictions = rf_regressor.predict(X_test)

# Calculate evaluation metrics
rmse = mean_squared_error(y_test, predictions)
rrmse = np.sqrt(rmse)
rmae = mean_absolute_error(y_test, predictions)
#r_squared = r2_score(y_test, predictions)

print(f"Mean Squared Error (MSE): {rmse:.2f}")
print(f"Root Mean Squared Error (RMSE): {rrmse:.2f}")
print(f"Mean Absolute Error (MAE): {rmae:.2f}")
#print(f"R-squared (R2): {r_squared}")
# Out:
# Mean Squared Error (MSE): 0.21
# Root Mean Squared Error (RMSE): 0.46
# Mean Absolute Error (MAE): 0.43

# %%
import pickle

pickle.dump(rf_regressor, open('model.pkl','wb'))

model = pickle.load(open('model.pkl','rb'))
